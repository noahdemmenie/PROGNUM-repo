# %% [markdown]
# Answers for Week 2
#
# * Name: Noah Demmenie
# * Username: ndemmenie
# * Student s-number: S6294588
# * Group (AS1, etc.): AS3

# %% [markdown]
# **Question 2.5 : LaTeX formulas in a notebook:**

# %% [markdown]
# $$\sum_{k=0}^{\infty} \frac{1}{4k^2-1} = \frac{1}{2}$$
# $$\int\limits_0^{2\pi} e^{ix}dx = 2i$$

# %% [markdown]
# **Question 2.12 : Quadrants:**

# %%
from math import atan2, degrees

# input variables for the x and y coordinate

x = float(input("Enter x"))
y = float(input("Enter y"))

# Compute angle between the x axis and the line between origin and (x,y)

angle_rad = atan2(y, x) 
angle_deg = degrees(angle_rad)
print(f"Angle = {angle_deg}")

# Determine the quadrant based on the angle

if 0 < angle_deg < 90:
    quadrant = "I"
elif 90 < angle_deg < 180:
    quadrant = "II"
elif -90 < angle_deg < 0:
    quadrant = "IV"
elif -180 < angle_deg < -90:
    quadrant = "III"
else:
    quadrant = "on an axis"

print(f"It lies in quadrant {quadrant}")
# Out:
# Enter x -3
# Enter y 2
# Angle = 146.30993247402023
# It lies in quadrant II

# %% [markdown]
# The difference between atan and atan2 is that atan computes arctan(y/x) and returns values in (−pi/2, pi/2), so it cannot determine the correct quadrant. atan2 uses both x and y to determine the correct quadrant and returns values in (−pi, pi).

# %% [markdown]
# **Question 2.14 : Exercise with slice():**

# %%
# Original list of values

X = [1.36, 1.46, 1.41, 2.12, 0.42, 0.98, 0.45, 1.97, -0.24, 2.18]

# Modify the list

X.append(0.51)
X.remove(2.12)

print(f"list = {X}")

# Create slice object: start at index 2, stop at -2, step size 2

indices = slice(2,-2, 2)

# Apply slicing to list

X_sliced = X[indices]

# Compute sum of sliced values

sum_X_sliced = sum(X_sliced)

print(f"sliced list = {X_sliced}")
print(f"sum sliced list = {sum_X_sliced}")
# Out:
# list = [1.36, 1.46, 1.41, 0.42, 0.98, 0.45, 1.97, -0.24, 2.18, 0.51]
# sliced list = [1.41, 0.98, 1.97]
# sum sliced list = 4.359999999999999

# %% [markdown]
# Value at index 6 is 1.97
#
# Index of value 1.46 is 1

# %% [markdown]
# **Question 2.15 : Intersection of two lists:**

# %%
# Lists for night1 and night2

night1 = [1,3,2,4,0,3,7,5,2,9,2,4,3]
night2 = [0,0,2,4,2,4,3,2,1,1,1,2,0]

# Convert lists to sets

n1_set = set(night1)
n2_set = set(night2)

# Intersection of night1 and night2

inters = set.intersection(n1_set, n2_set)

# Convert intersection set back to list

list_inters = list(inters)
print(f"Intersection night1 and night2 = {list_inters}")

# Check whether 5 is in the intersection

if 5 in inters:
    print("5 IS an element in the intersection list")
else:
    print("5 is NOT an element in the intersection list")

# Check whether 5 is in night1

if 5 in night1:
    print("5 IS an element in the night1 list")
else:
    print("5 is NOT an element in the night list")
# Out:
# Intersection night1 and night2 = [0, 1, 2, 3, 4]
# 5 is NOT an element in the intersection list
# 5 IS an element in the night1 list

# %% [markdown]
# **Question 2.19 : First steps using NumPy arrays:**

# %%
import numpy as np
mu, sigma = 0, 1.4 # mean and standard deviation

# Generate 100000 random values from a normal distribution

s = np.random.normal(mu, sigma, 100000)
# Compute standard deviation

s_d = abs(sigma - np.std(s, ddof=1))
print(f"standard deviation = {s_d}")
# Out:
# standard deviation = 0.003789968031884916

# %% [markdown]
# **Question 2.21 : Fibonacci sequence:**

# %%
# Starting values of Fibonacci sequence

a = 1
b = 2

# Compute the 100th Fibonacci term

for i in range(99):
    c = a + b
    a = b
    b = c
print(f"100-th term = {a}")
# Out:
# 100-th term = 573147844013817084101

# %% [markdown]
# ![image.png](attachment:cf495629-3de4-4a45-b6fd-a0854a52d111.png)

# %% [markdown]
# **Question 2.26 : delete folder and recap GitHub:**

# %% [markdown]
# ![image.png](attachment:a7d106d5-7526-4f1a-a079-6494d6ea3113.png)
