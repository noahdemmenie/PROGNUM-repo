# %% [markdown]
# Answers for Week 1
#
# * Name: Noah Demmenie
# * Username: ndemmenie
# * Student s-number: S6294588
# * Group (AS1, etc.): AS3

# %% [markdown]
# Question 1.2 : First Session Quiz in a notebook

# %%
x = 22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %% [markdown]
# Question 1.5 : Gravitational pull

# %%
from scipy.constants import G

m_moon = 7.342e22
m_earth = 5.9722e24
r = 385000.6e3

F = G * (m_moon * m_earth)/r**2
print("F =",F)
# Out:
# F = 1.974384051807571e+20

# %% [markdown]
# Question 1.10 : Transfer a file between two machines

# %% [markdown]
# ![image.png](attachment:8f6f4ee1-be18-49c2-adc7-19a1010cf336.png)

# %% [markdown]
# Question 1.11 : Create a directory structure for your tasks

# %% [markdown]
# ![Screenshot%20from%202026-02-11%2016-03-52.png](attachment:Screenshot%20from%202026-02-11%2016-03-52.png)

# %% [markdown]
# Question 1.12 : Copy you notebooks to another directory

# %% [markdown]
# ![Screenshot_20260211_163946.png](attachment:Screenshot_20260211_163946.png)
